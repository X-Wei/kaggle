# %% [markdown]
# # Feature Engineering for Forest_Cover_Type

# %% [markdown]
# This ipynb contains attempts to do feature engineering with the data.
#
# Reference: http://nbviewer.ipython.org/github/aguschin/kaggle/blob/master/forestCoverType_featuresEngineering.ipynb

# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Reading data

# %%
train = pd.read_csv('csv_data/train.csv')
#df_train12 = pd.read_csv('csv_data/train_cls12.csv')
#df_train37 = pd.read_csv('csv_data/train_cls37.csv')
test= pd.read_csv('csv_data/test.csv')

# %%
train.ix[0:1,1 :11]
# Out:
#    Elevation  Aspect  Slope  Horizontal_Distance_To_Hydrology  \
# 0       2596      51      3                               258
# 1       2590      56      2                               212
#
#    Vertical_Distance_To_Hydrology  Horizontal_Distance_To_Roadways  \
# 0                               0                              510
# 1                              -6                              390
#
#    Hillshade_9am  Hillshade_Noon  Hillshade_3pm  \
# 0            221             232            148
# 1            220             235            151
#
#    Horizontal_Distance_To_Fire_Points
# 0                                6279
# 1                                6225

# %% [markdown]
# ### Look at the non-categorical attributes

# %%
train.ix[:,1:11].hist(figsize=(16,12),bins=50)
plt.show()

# %% [markdown]
# ###  Aspect is in degrees azimuth(方位角), shift it at 180

# %% [markdown]
# **(目的是使得地理位置上接近的地点(如方位角=5和方位角=355的两处)在Aspect或Aspect2的某一个上接近)**

# %%
def rotate180(x):
        return x-180 if x>180 else x+180

train['Aspect2'] = train.Aspect.map(rotate180)
test['Aspect2'] = test.Aspect.map(rotate180)

# %% [markdown]
# ### Create variable which indicates positive or negative value for `Vertical_Distance_To_Hydrology`

# %%
train['Highwater'] = train.Vertical_Distance_To_Hydrology < 0
test['Highwater'] = test.Vertical_Distance_To_Hydrology < 0

# %% [markdown]
# ### Look at correlation

# %%
def plot_cov(c1,c2):
    '''
    Plot cov-plots between columns, c1 in X-axis, c2 in Y-axis
    '''
    fig = plt.figure(figsize=(16,8))
    sel = train.Cover_Type.values
    plt.scatter(c1, c2, c=sel, s=100)
    plt.xlabel(c1.name)
    plt.ylabel(c2.name)

# %%
plot_cov(train.Elevation, train.Vertical_Distance_To_Hydrology)

# %%
plot_cov(train.Elevation-train.Vertical_Distance_To_Hydrology, train.Vertical_Distance_To_Hydrology)

# %%
plot_cov(train.Elevation, train.Horizontal_Distance_To_Hydrology)

# %%
train['Elv-Vdist'] = train.Elevation - train.Vertical_Distance_To_Hydrology
test['Elv-Vdist'] = test.Elevation - test.Vertical_Distance_To_Hydrology

# %% [markdown]
# ### Doing as what Alexander Guschin suggests:

# %%
train['EHDtH'] = train.Elevation-train.Horizontal_Distance_To_Hydrology*0.2
test['EHDtH'] = test.Elevation-test.Horizontal_Distance_To_Hydrology*0.2
train['Distanse_to_Hydrolody'] = (train['Horizontal_Distance_To_Hydrology']**2+train['Vertical_Distance_To_Hydrology']**2)**0.5
test['Distanse_to_Hydrolody'] = (test['Horizontal_Distance_To_Hydrology']**2+test['Vertical_Distance_To_Hydrology']**2)**0.5

train['Hydro_Fire_1'] = train['Horizontal_Distance_To_Hydrology']+train['Horizontal_Distance_To_Fire_Points']
test['Hydro_Fire_1'] = test['Horizontal_Distance_To_Hydrology']+test['Horizontal_Distance_To_Fire_Points']

train['Hydro_Fire_2'] = abs(train['Horizontal_Distance_To_Hydrology']-train['Horizontal_Distance_To_Fire_Points'])
test['Hydro_Fire_2'] = abs(test['Horizontal_Distance_To_Hydrology']-test['Horizontal_Distance_To_Fire_Points'])

train['Hydro_Road_1'] = abs(train['Horizontal_Distance_To_Hydrology']+train['Horizontal_Distance_To_Roadways'])
test['Hydro_Road_1'] = abs(test['Horizontal_Distance_To_Hydrology']+test['Horizontal_Distance_To_Roadways'])

train['Hydro_Road_2'] = abs(train['Horizontal_Distance_To_Hydrology']-train['Horizontal_Distance_To_Roadways'])
test['Hydro_Road_2'] = abs(test['Horizontal_Distance_To_Hydrology']-test['Horizontal_Distance_To_Roadways'])

train['Fire_Road_1'] = abs(train['Horizontal_Distance_To_Fire_Points']+train['Horizontal_Distance_To_Roadways'])
test['Fire_Road_1'] = abs(test['Horizontal_Distance_To_Fire_Points']+test['Horizontal_Distance_To_Roadways'])

train['Fire_Road_2'] = abs(train['Horizontal_Distance_To_Fire_Points']-train['Horizontal_Distance_To_Roadways'])
test['Fire_Road_2'] = abs(test['Horizontal_Distance_To_Fire_Points']-test['Horizontal_Distance_To_Roadways'])

# %%
#train.to_csv('train_FE2.csv', index = False)
#test.to_csv('test_FE2.csv', index = False)

# %%
plot_cov(train.Slope, train.Hillshade_Noon)

# %%
plot_cov(train.Hillshade_Noon, train.Hillshade_3pm)

# %% [markdown]
# **There are missing values for `hillshade_3pm`**

# %%
hs3pm =  train.Hillshade_3pm
hs3pm.value_counts()[0]
# Out:
# 88

# %% [markdown]
# **only 88 instances... maybe this isn't a missing value ??**

# %%
plot_cov(train.Hillshade_Noon, train.Hillshade_9am)

# %%
train.Hillshade_9am.value_counts()[0]
# Out:
# 1

# %% [markdown]
# ### Oversampling for class 1 and 2?

# %%
print len(train)
train.Cover_Type.value_counts()
# Out:
# 15120
# 7    2160
# 6    2160
# 5    2160
# 4    2160
# 3    2160
# 2    2160
# 1    2160
# dtype: int64

# %%
train_c12 = train[train.Cover_Type<3]
print len(train_c12)
#train_c12['Id'] = train_c12['Id']+len(train)
train_c12.head()
# Out:
# 4320
#     Id  Elevation  Aspect  Slope  Horizontal_Distance_To_Hydrology  \
# 2    3       2804     139      9                               268
# 3    4       2785     155     18                               242
# 5    6       2579     132      6                               300
# 11  12       2886     151     11                               371
# 12  13       2742     134     22                               150
#
#     Vertical_Distance_To_Hydrology  Horizontal_Distance_To_Roadways  \
# 2                               65                             3180
# 3                              118                             3090
# 5                              -15                               67
# 11                              26                             5253
# 12                              69                             3215
#
#     Hillshade_9am  Hillshade_Noon  Hillshade_3pm     ...       Highwater  \
# 2             234             238            135     ...           False
# 3             238             238            122     ...           False
# 5             230             237            140     ...            True
# 11            234             240            136     ...           False
# 12            248             224             92     ...           False
#
#     Elv-Vdist   EHDtH  Distanse_to_Hydrolody  Hydro_Fire_1  Hydro_Fire_2  \
# 2        2739  2750.4             275.769832          6389          5853
# 3        2667  2736.6             269.235956          6453          5969
# 5        2594  2519.0             300.374766          6331          5731
# 11       2860  2811.8             371.909935          4422          3680
# 12       2673  2712.0             165.109055          6241          5941
#
#     Hydro_Road_1  Hydro_Road_2  Fire_Road_1  Fire_Road_2
# 2           3448          2912         9301         2941
# 3           3332          2848         9301         3121
# 5            367           233         6098         5964
# 11          5624          4882         9304         1202
# 12          3365          3065         9306         2876
#
# [5 rows x 67 columns]

# %% [markdown]
# **oversampling 10 times the class 1 and 2**

# %%
#adding more instances for classes 12
for i in range(10):
    train = pd.concat([train, train_c12])
    len(train)

# %%
train.Cover_Type.value_counts()
# Out:
# 2    23760
# 1    23760
# 7     2160
# 6     2160
# 5     2160
# 4     2160
# 3     2160
# dtype: int64

# %%
train.to_csv('train_FE3.csv', index = False)
#test.to_csv('test_FE2.csv', index = False)
